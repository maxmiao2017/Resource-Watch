# %%
from sys import argv
import urllib
try:
    from http.cookiejar import CookieJar
except ImportError:
    from cookielib import CookieJar
from urllib.parse import urlencode

# %%
username = "max2017 "
password = "Lounge38"

# The url of the file we wish to retrieve
 
url = "http://e4ftl01.cr.usgs.gov/MOLA/MYD17A3H.006/2009.01.01/MYD17A3H.A2009001.h12v05.006.2015198130546.hdf.xml"
 
 
# Create a password manager to deal with the 401 reponse that is returned from
# Earthdata Login
 
password_manager =  urllib.request.HTTPPasswordMgrWithDefaultRealm()
password_manager.add_password(None, "https://urs.earthdata.nasa.gov", username, password)
 
 
# Create a cookie jar for storing cookies. This is used to store and return
# the session cookie given to use by the data server (otherwise it will just
# keep sending us back to Earthdata Login to authenticate).  Ideally, we
# should use a file based cookie jar to preserve cookies between runs. This
# will make it much more efficient.
 
cookie_jar = CookieJar()
  
 
# Install all the handlers.
 
opener = urllib.request.build_opener(
    urllib.request.HTTPBasicAuthHandler(password_manager),
    #urllib2.HTTPHandler(debuglevel=1),    # Uncomment these two lines to see
    #urllib2.HTTPSHandler(debuglevel=1),   # details of the requests/responses
    urllib.request.HTTPCookieProcessor(cookie_jar))
urllib.request.install_opener(opener)

# %%
outputFolder = "/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/"
outputFolder_Africa = "/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/Africa/"
inputFile = outputFolder+'C1429296018-LPDAAC_ECS_data_urls.txt'

# %%
file = open(inputFile)
    # looping over the file: line by line
try:
    file = open(inputFile)
    # looping over the file: line by line
    with file as f:
        for line in f:
            # taking everything after the last / as filename
            # outputFolder has to exist beforehand
            print (line)
            filename = outputFolder + line.split('/')[-1].strip()
            print ("\nTrying to download " + line.strip())
            print(filename)
            try:
                # downloading file, continues with error message when not found
                urllib.request.urlretrieve(line, filename)
                print ('Saved as ' + filename)
            except IOError:
                print ('Could not find file')
                pass
except IOError:
    print ('Could not find file2')
    pass
# Out:
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# Saved as /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
# ---------------------------------------------------------------------------
# ...

# %%
file = open(inputFile)
    # looping over the file: line by line
try:
    file = open(inputFile)
    # looping over the file: line by line
    with file as f:
        for line in f:
            # taking everything after the last / as filename
            # outputFolder has to exist beforehand
            print (line)
            filename = outputFolder_Africa + line.split('/')[-1].strip()
            print ("\nTrying to download " + line.strip())
            print(filename)
            try:
                # downloading file, continues with error message when not found
                urllib.request.urlretrieve(line, filename)
                print ('Saved as ' + filename)
            except IOError:
                print ('Could not find file')
                pass
except IOError:
    print ('Could not find file2')
    pass
# Out:
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/Africa/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# Saved as /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/Africa/GFSAD30AFCE_2015_N10E50_001_2017261090100.tif
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/Africa/GFSAD30AFCE_2015_S20E30_001_2017261090100.tif
# ...

# %%
outputFolder_China = "/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/China/"
inputFile = outputFolder+'C1431392676-LPDAAC_ECS_data_urls.txt'

file = open(inputFile)
    # looping over the file: line by line
try:
    file = open(inputFile)
    # looping over the file: line by line
    with file as f:
        for line in f:
            # taking everything after the last / as filename
            # outputFolder has to exist beforehand
            print (line)
            filename = outputFolder_China + line.split('/')[-1].strip()
            print ("\nTrying to download " + line.strip())
            print(filename)
            try:
                # downloading file, continues with error message when not found
                urllib.request.urlretrieve(line, filename)
                print ('Saved as ' + filename)
            except IOError:
                print ('Could not find file')
                pass
except IOError:
    print ('Could not find file2')
    pass
# Out:
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AUNZCNMOCE.001/2013.01.01/GFSAD30AUNZCNMOCE_2015_S40E160_001_2017286154500.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AUNZCNMOCE.001/2013.01.01/GFSAD30AUNZCNMOCE_2015_S40E160_001_2017286154500.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/China/GFSAD30AUNZCNMOCE_2015_S40E160_001_2017286154500.tif
# Saved as /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/China/GFSAD30AUNZCNMOCE_2015_S40E160_001_2017286154500.tif
# https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AUNZCNMOCE.001/2013.01.01/GFSAD30AUNZCNMOCE_2015_S60E110_001_2017286154500.tif
#
#
# Trying to download https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AUNZCNMOCE.001/2013.01.01/GFSAD30AUNZCNMOCE_2015_S60E110_001_2017286154500.tif
# /Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/China/GFSAD30AUNZCNMOCE_2015_S60E110_001_2017286154500.tif
# ...

# %%
outputFolder_China = "/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048/China/"
inputFile = outputFolder+'C1431392676-LPDAAC_ECS_data_urls.txt'

file = open(inputFile)
    # looping over the file: line by line
try:
    file = open(inputFile)
    # looping over the file: line by line
    with file as f:
        for line in f:
            # taking everything after the last / as filename
            # outputFolder has to exist beforehand
            print (line)
            filename = outputFolder_China + line.split('/')[-1].strip()
            print ("\nTrying to download " + line.strip())
            print(filename)
            try:
                # downloading file, continues with error message when not found
                urllib.request.urlretrieve(line, filename)
                print ('Saved as ' + filename)
            except IOError:
                print ('Could not find file')
                pass
except IOError:
    print ('Could not find file2')
    pass

# %%
urllib.request.urlretrieve('https://e4ftl01.cr.usgs.gov//MODV6_Dal_G/MEASURES/GFSAD30AFCE.001/2013.01.01/GFSAD30AFCE_2015_S30E20_001_2017261090100.tif', '/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048//nax.tif')          , ''
# Out:
# (('/Users/Max81007/Desktop/Python/Resource_Watch/Raster/foo.048//nax.tif',
#   <http.client.HTTPMessage at 0x13a8710>),
#  '')
